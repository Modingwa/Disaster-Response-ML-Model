# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# Load Libraries
import pandas as pd
import numpy as np
import re
import warnings

import pickle

from sqlalchemy import create_engine

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import fbeta_score, make_scorer

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn import multioutput
from sklearn.multioutput import MultiOutputClassifier
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report

import nltk
nltk.download(['punkt', 'wordnet'])
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Charles\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Charles\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# define project directory
projects_dir = "D:/DSN Projects/Disaster-Response-ML-Model/"

# %% [markdown]
# ## Load Dataset

# %%
def load_data():
    """Function to tokenize text

    Parameters
    ----------
    none

    Returns
    -------
    Pandas DataFrame
    """
    # load data from database
    engine = create_engine('sqlite:///{}/data//DisasterResponse.db'.format(projects_dir))
    df = pd.read_sql_table('messages', engine)
    
    X =  df['message']
    y =  df.iloc[:,4:]
    return X, y

# %%
X, y = load_data()

# %% [markdown]
# ### Utility functions

# %%
def consolidate_classification_reports(y_test, y_pred):
    # covert to dataframe for reprting purposes
    y_pred = pd.DataFrame (y_pred, columns = y_test.columns)
    
    feature_scores = pd.DataFrame()
    
    for col in y_test.columns:
        # get classification report in dictionary format
        report_dict = classification_report(y_test[col],y_pred[col], output_dict=True)
        
        # convert report to dataframe
        report_df = pd.DataFrame.from_dict(report_dict)
        
        # remove unnecessary support row
        report_df = report_df.iloc[:-1]
        
        #lets drop unnecessary columns
        report_df.drop(['micro avg', 'macro avg', 'weighted avg'], axis =1, inplace = True)
        
        # calculate the average scores
        report_df = pd.DataFrame(report_df.transpose().mean())
        
        # reshape df
        report_df = report_df.transpose()
        
        feature_scores = feature_scores.append(report_df, ignore_index=True)
    return feature_scores

# %%
def print_classification_results(y_test, y_pred):
    # covert to dataframe for reprting purposes
    y_pred = pd.DataFrame (y_pred, columns = y_test.columns)
    for col in y_test.columns:
        print('Category feature : {}'.format(col.capitalize()))
        print('.................................................................\n')
        print(classification_report(y_test[col],y_pred[col]))

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    """Function to tokenize text

    Parameters
    ----------
    text : str
        String to tokenize

    Returns
    -------
    List
        List of tokenized words
    """
    url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")

    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
# Baseline pipeline
def build_model():
    pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(RandomForestClassifier())),
    ])
    return pipeline

# %%
# optimised model using AdaBoost Classifier instead of random forest
def build_new_model():
    pipeline = Pipeline([
        ('features', FeatureUnion([

            ('text_pipeline', Pipeline([
                ('vect', CountVectorizer(tokenizer=tokenize)),
                ('tfidf', TfidfTransformer())
            ]))
        ])),

        ('clf', MultiOutputClassifier(AdaBoostClassifier()))
    ])

    return pipeline

# %%
pipeline = build_model()

# %%
print(pipeline)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip..._score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=None))])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
# train classifier
with warnings.catch_warnings():
    warnings.simplefilter("ignore") # ignore future warnings
    pipeline.fit(X_train, y_train)

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
y_pred = pipeline.predict(X_test)

# %%
print_classification_results(y_test, y_pred)
# Out:
# Category feature : Related
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.10      0.15      1569
#          1.0       0.76      0.93      0.84      4894
#
#    micro avg       0.73      0.73      0.73      6463
#    macro avg       0.55      0.52      0.50      6463
# weighted avg       0.66      0.73      0.67      6463
#
# Category feature : Request
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.98      0.90      5329
#          1.0       0.50      0.08      0.14      1134
#
#    micro avg       0.82      0.82      0.82      6463
#    macro avg       0.67      0.53      0.52      6463
# weighted avg       0.77      0.82      0.77      6463
#
# Category feature : Offer
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6432
#          1.0       0.00      0.00      0.00        31
#
#    micro avg       1.00      1.00      1.00      6463
#    macro avg       0.50      0.50      0.50      6463
# weighted avg       0.99      1.00      0.99      6463
#
# Category feature : Aid_related
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.82      0.69      3788
#          1.0       0.47      0.22      0.30      2675
#
#    micro avg       0.57      0.57      0.57      6463
#    macro avg       0.53      0.52      0.50      6463
# weighted avg       0.55      0.57      0.53      6463
#
# Category feature : Medical_help
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96      5954
#          1.0       0.00      0.00      0.00       509
#
#    micro avg       0.92      0.92      0.92      6463
#    macro avg       0.46      0.50      0.48      6463
# weighted avg       0.85      0.92      0.88      6463
#
# Category feature : Medical_products
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      6131
#          1.0       0.05      0.00      0.01       332
#
#    micro avg       0.95      0.95      0.95      6463
#    macro avg       0.50      0.50      0.49      6463
# weighted avg       0.90      0.95      0.92      6463
#
# Category feature : Search_and_rescue
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6309
#          1.0       0.00      0.00      0.00       154
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.49      0.50      0.49      6463
# weighted avg       0.95      0.98      0.96      6463
#
# Category feature : Security
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6341
#          1.0       0.00      0.00      0.00       122
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.49      0.50      0.50      6463
# weighted avg       0.96      0.98      0.97      6463
#
# Category feature : Military
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98      6244
#          1.0       0.20      0.00      0.01       219
#
#    micro avg       0.97      0.97      0.97      6463
#    macro avg       0.58      0.50      0.50      6463
# weighted avg       0.94      0.97      0.95      6463
#
# Category feature : Child_alone
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6463
#
#    micro avg       1.00      1.00      1.00      6463
#    macro avg       1.00      1.00      1.00      6463
# weighted avg       1.00      1.00      1.00      6463
#
# Category feature : Water
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96      6025
#          1.0       0.10      0.00      0.01       438
#
#    micro avg       0.93      0.93      0.93      6463
#    macro avg       0.51      0.50      0.49      6463
# weighted avg       0.88      0.93      0.90      6463
#
# Category feature : Food
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.88      1.00      0.94      5711
#          1.0       0.21      0.01      0.01       752
#
#    micro avg       0.88      0.88      0.88      6463
#    macro avg       0.55      0.50      0.47      6463
# weighted avg       0.81      0.88      0.83      6463
#
# Category feature : Shelter
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95      5905
#          1.0       0.12      0.01      0.01       558
#
#    micro avg       0.91      0.91      0.91      6463
#    macro avg       0.52      0.50      0.48      6463
# weighted avg       0.85      0.91      0.87      6463
#
# Category feature : Clothing
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6342
#          1.0       0.00      0.00      0.00       121
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.49      0.50      0.50      6463
# weighted avg       0.96      0.98      0.97      6463
#
# Category feature : Money
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6311
#          1.0       0.00      0.00      0.00       152
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.49      0.50      0.49      6463
# weighted avg       0.95      0.98      0.96      6463
#
# Category feature : Missing_people
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      6403
#          1.0       0.00      0.00      0.00        60
#
#    micro avg       0.99      0.99      0.99      6463
#    macro avg       0.50      0.50      0.50      6463
# weighted avg       0.98      0.99      0.99      6463
#
# Category feature : Refugees
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98      6262
#          1.0       0.17      0.00      0.01       201
#
#    micro avg       0.97      0.97      0.97      6463
#    macro avg       0.57      0.50      0.50      6463
# weighted avg       0.94      0.97      0.95      6463
#
# Category feature : Death
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98      6186
#          1.0       0.00      0.00      0.00       277
#
#    micro avg       0.96      0.96      0.96      6463
#    macro avg       0.48      0.50      0.49      6463
# weighted avg       0.92      0.96      0.94      6463
#
# Category feature : Other_aid
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.99      0.92      5620
#          1.0       0.07      0.01      0.01       843
#
#    micro avg       0.86      0.86      0.86      6463
#    macro avg       0.47      0.50      0.47      6463
# weighted avg       0.76      0.86      0.81      6463
#
# Category feature : Infrastructure_related
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97      6052
#          1.0       0.20      0.01      0.01       411
#
#    micro avg       0.94      0.94      0.94      6463
#    macro avg       0.57      0.50      0.49      6463
# weighted avg       0.89      0.94      0.91      6463
#
# Category feature : Transport
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      6151
#          1.0       0.00      0.00      0.00       312
#
#    micro avg       0.95      0.95      0.95      6463
#    macro avg       0.48      0.50      0.49      6463
# weighted avg       0.91      0.95      0.93      6463
#
# Category feature : Buildings
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      6149
#          1.0       0.12      0.01      0.01       314
#
#    micro avg       0.95      0.95      0.95      6463
#    macro avg       0.53      0.50      0.49      6463
# weighted avg       0.91      0.95      0.93      6463
#
# Category feature : Electricity
# .................................................................
# C:\Users\Charles\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6341
#          1.0       0.00      0.00      0.00       122
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.49      0.50      0.50      6463
# weighted avg       0.96      0.98      0.97      6463
#
# Category feature : Tools
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      6425
#          1.0       0.00      0.00      0.00        38
#
#    micro avg       0.99      0.99      0.99      6463
#    macro avg       0.50      0.50      0.50      6463
# weighted avg       0.99      0.99      0.99      6463
#
# Category feature : Hospitals
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6393
#          1.0       0.00      0.00      0.00        70
#
#    micro avg       0.99      0.99      0.99      6463
#    macro avg       0.49      0.50      0.50      6463
# weighted avg       0.98      0.99      0.98      6463
#
# Category feature : Shops
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      6429
#          1.0       0.00      0.00      0.00        34
#
#    micro avg       0.99      0.99      0.99      6463
#    macro avg       0.50      0.50      0.50      6463
# weighted avg       0.99      0.99      0.99      6463
#
# Category feature : Aid_centers
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6387
#          1.0       0.00      0.00      0.00        76
#
#    micro avg       0.99      0.99      0.99      6463
#    macro avg       0.49      0.50      0.50      6463
# weighted avg       0.98      0.99      0.98      6463
#
# Category feature : Other_infrastructure
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98      6186
#          1.0       0.43      0.01      0.02       277
#
#    micro avg       0.96      0.96      0.96      6463
#    macro avg       0.69      0.51      0.50      6463
# weighted avg       0.93      0.96      0.94      6463
#
# Category feature : Weather_related
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.95      0.83      4633
#          1.0       0.52      0.15      0.23      1830
#
#    micro avg       0.72      0.72      0.72      6463
#    macro avg       0.63      0.55      0.53      6463
# weighted avg       0.68      0.72      0.66      6463
#
# Category feature : Floods
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96      5943
#          1.0       0.25      0.00      0.01       520
#
#    micro avg       0.92      0.92      0.92      6463
#    macro avg       0.58      0.50      0.48      6463
# weighted avg       0.87      0.92      0.88      6463
#
# Category feature : Storm
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.91      1.00      0.95      5843
#          1.0       0.42      0.03      0.06       620
#
#    micro avg       0.90      0.90      0.90      6463
#    macro avg       0.66      0.51      0.51      6463
# weighted avg       0.86      0.90      0.86      6463
#
# Category feature : Fire
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6390
#          1.0       0.00      0.00      0.00        73
#
#    micro avg       0.99      0.99      0.99      6463
#    macro avg       0.49      0.50      0.50      6463
# weighted avg       0.98      0.99      0.98      6463
#
# Category feature : Earthquake
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.99      0.95      5831
#          1.0       0.76      0.16      0.26       632
#
#    micro avg       0.91      0.91      0.91      6463
#    macro avg       0.84      0.58      0.61      6463
# weighted avg       0.90      0.91      0.89      6463
#
# Category feature : Cold
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6345
#          1.0       0.00      0.00      0.00       118
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.49      0.50      0.50      6463
# weighted avg       0.96      0.98      0.97      6463
#
# Category feature : Other_weather
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      6113
#          1.0       0.43      0.01      0.02       350
#
#    micro avg       0.95      0.95      0.95      6463
#    macro avg       0.69      0.50      0.49      6463
# weighted avg       0.92      0.95      0.92      6463
#
# Category feature : Direct_report
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.98      0.88      5190
#          1.0       0.38      0.06      0.10      1273
#
#    micro avg       0.80      0.80      0.80      6463
#    macro avg       0.59      0.52      0.49      6463
# weighted avg       0.72      0.80      0.73      6463

# %%
scores = consolidate_classification_reports(y_test, y_pred)
scores.index = y_test.columns

# %%
scores.head()
# Out:
#               f1-score  precision    recall
# related       0.497663   0.546344  0.517465
# request       0.518916   0.665456  0.530797
# offer         0.498798   0.497602  0.500000
# aid_related   0.497903   0.533936  0.522205
# medical_help  0.478958   0.460543  0.498908

# %%
overall_accuracy = (y_pred == y_test).mean().mean()*100
print('Overall Accuracy: {0:.1f} %'.format(overall_accuracy))
# Out:
# Overall Accuracy: 92.4 %

# %%
scores['f1-score'].mean()
# Out:
# 0.5113479430172512

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
def multioutput_f1_scorer(y_test, y_pred): 

    # covert to dataframe for reprting purposes
    y_pred = pd.DataFrame (y_pred, columns = y_test.columns)
    
    feature_scores = pd.DataFrame()
    
    for col in y_test.columns:
        # get classification report in dictionary format
        report_dict = classification_report(y_test[col],y_pred[col], output_dict=True)
        
        # convert report to dataframe
        report_df = pd.DataFrame.from_dict(report_dict)
        
        # remove unnecessary support row
        report_df = report_df.iloc[:-1]
        
        #lets drop unnecessary columns
        report_df.drop(['micro avg', 'macro avg', 'weighted avg'], axis=1, inplace = True)
        
        # calculate the average scores
        report_df = pd.DataFrame(report_df.transpose().mean())
        
        # reshape df
        report_df = report_df.transpose()
        
        feature_scores = feature_scores.append(report_df, ignore_index=True)
    # for grid search, return the overall f1 score for all features
    return feature_scores['f1-score'].mean()

# %%
# create scoring object for grid search
scorer = make_scorer(multioutput_f1_scorer, greater_is_better = True)

parameters = { 
    'clf__estimator__n_estimators': [50,100],
    'features__text_pipeline__vect__ngram_range': ((1, 1), (1, 2)),
    'features__text_pipeline__vect__max_df': (0.75, 1.0),
    'features__text_pipeline__tfidf__use_idf': (True, False)
}

new_pipeline = build_new_model()

X_train, X_test, y_train, y_test = train_test_split(X, y)

cv = GridSearchCV(new_pipeline, param_grid=parameters, scoring=scorer, verbose=2)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
cv.fit(X_train, y_train)
# Out:
# C:\Users\Charles\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.4min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.8min remaining:    0.0s
# C:\Users\Charles\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.4min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1)
# C:\Users\Charles\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.4min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2), total= 3.8min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2), total= 3.6min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2), total= 3.6min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.3min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.3min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.3min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2), total= 3.6min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2), total= 3.6min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2), total= 3.7min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.1min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.1min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.1min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2), total= 3.3min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2), total= 3.4min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2), total= 3.5min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.1min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1)
# C:\Users\Charles\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.2min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.1min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2), total= 3.3min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2), total= 3.3min
# [CV] clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=50, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2), total= 3.4min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1), total= 2.2min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1), total= 2.2min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1), total= 2.2min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2), total= 6.8min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2), total= 6.8min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2), total= 7.0min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1), total= 2.3min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1), total= 2.3min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1), total= 2.3min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2), total= 6.9min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2), total= 6.9min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=True, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2), total= 6.9min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.9min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.9min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 1), total= 2.0min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2), total= 6.2min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2), total= 6.4min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=0.75, features__text_pipeline__vect__ngram_range=(1, 2), total= 6.5min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.9min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.9min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 1), total= 1.9min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2), total= 6.2min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2), total= 6.3min
# [CV] clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2)
# [CV]  clf__estimator__n_estimators=100, features__text_pipeline__tfidf__use_idf=False, features__text_pipeline__vect__max_df=1.0, features__text_pipeline__vect__ngram_range=(1, 2), total= 6.4min
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed: 184.4min finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('features', FeatureUnion(n_jobs=None,
#        transformer_list=[('text_pipeline', Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, ma...or=None,
#           learning_rate=1.0, n_estimators=50, random_state=None),
#            n_jobs=None))]),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'clf__estimator__n_estimators': [50, 100], 'features__text_pipeline__vect__ngram_range': ((1, 1), (1, 2)), 'features__text_pipeline__vect__max_df': (0.75, 1.0), 'features__text_pipeline__tfidf__use_idf': (True, False)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(multioutput_f1_scorer), verbose=2)

# %%
# lets test the new model 
y_pred_new = cv.predict(X_test)

# %%
new_overall_accuracy = (y_pred_new == y_test).mean().mean()*100
print('Overall Accuracy: {0:.1f} %'.format(new_overall_accuracy))
# Out:
# Overall Accuracy: 92.2 %

# %%
# new scores
new_scores = consolidate_classification_reports(y_test, y_pred_new)
new_scores.index = y_test.columns

# %%
# lets calculate the % change in overall F1 Score
change = new_scores['f1-score'].mean() - scores['f1-score'].mean()
percent_change = 100*change/scores['f1-score'].mean()

# %%
print('Overall F1 Score increases by {0:.2f} %'.format(percent_change))
# Out:
# Overall F1 Score increases by 1.17 %

# %%
print_classification_results(y_test, y_pred_new)
# Out:
# Category feature : Related
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.06      0.11      1542
#          1.0       0.77      0.96      0.85      4921
#
#    micro avg       0.75      0.75      0.75      6463
#    macro avg       0.56      0.51      0.48      6463
# weighted avg       0.67      0.75      0.68      6463
#
# Category feature : Request
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.95      0.90      5345
#          1.0       0.42      0.17      0.24      1118
#
#    micro avg       0.82      0.82      0.82      6463
#    macro avg       0.63      0.56      0.57      6463
# weighted avg       0.77      0.82      0.78      6463
#
# Category feature : Offer
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6441
#          1.0       0.10      0.05      0.06        22
#
#    micro avg       1.00      1.00      1.00      6463
#    macro avg       0.55      0.52      0.53      6463
# weighted avg       0.99      1.00      0.99      6463
#
# Category feature : Aid_related
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.85      0.70      3770
#          1.0       0.47      0.19      0.27      2693
#
#    micro avg       0.57      0.57      0.57      6463
#    macro avg       0.53      0.52      0.48      6463
# weighted avg       0.54      0.57      0.52      6463
#
# Category feature : Medical_help
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.95      5924
#          1.0       0.17      0.01      0.02       539
#
#    micro avg       0.91      0.91      0.91      6463
#    macro avg       0.54      0.50      0.49      6463
# weighted avg       0.85      0.91      0.88      6463
#
# Category feature : Medical_products
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      6142
#          1.0       0.24      0.01      0.02       321
#
#    micro avg       0.95      0.95      0.95      6463
#    macro avg       0.59      0.51      0.50      6463
# weighted avg       0.92      0.95      0.93      6463
#
# Category feature : Search_and_rescue
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98      6284
#          1.0       0.00      0.00      0.00       179
#
#    micro avg       0.97      0.97      0.97      6463
#    macro avg       0.49      0.50      0.49      6463
# weighted avg       0.95      0.97      0.96      6463
#
# Category feature : Security
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6339
#          1.0       0.06      0.01      0.01       124
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.52      0.50      0.50      6463
# weighted avg       0.96      0.98      0.97      6463
#
# Category feature : Military
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98      6238
#          1.0       0.00      0.00      0.00       225
#
#    micro avg       0.96      0.96      0.96      6463
#    macro avg       0.48      0.50      0.49      6463
# weighted avg       0.93      0.96      0.95      6463
#
# Category feature : Child_alone
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6463
#
#    micro avg       1.00      1.00      1.00      6463
#    macro avg       1.00      1.00      1.00      6463
# weighted avg       1.00      1.00      1.00      6463
#
# Category feature : Water
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97      6055
#          1.0       0.07      0.00      0.01       408
#
#    micro avg       0.93      0.93      0.93      6463
#    macro avg       0.51      0.50      0.49      6463
# weighted avg       0.88      0.93      0.91      6463
#
# Category feature : Food
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.99      0.94      5764
#          1.0       0.28      0.03      0.05       699
#
#    micro avg       0.89      0.89      0.89      6463
#    macro avg       0.59      0.51      0.49      6463
# weighted avg       0.83      0.89      0.84      6463
#
# Category feature : Shelter
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.99      0.95      5851
#          1.0       0.13      0.01      0.02       612
#
#    micro avg       0.90      0.90      0.90      6463
#    macro avg       0.52      0.50      0.49      6463
# weighted avg       0.83      0.90      0.86      6463
#
# Category feature : Clothing
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6376
#          1.0       0.03      0.01      0.02        87
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.51      0.50      0.50      6463
# weighted avg       0.97      0.98      0.98      6463
#
# Category feature : Money
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6319
#          1.0       0.03      0.01      0.01       144
#
#    micro avg       0.97      0.97      0.97      6463
#    macro avg       0.51      0.50      0.50      6463
# weighted avg       0.96      0.97      0.96      6463
#
# Category feature : Missing_people
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6376
#          1.0       0.00      0.00      0.00        87
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.49      0.50      0.50      6463
# weighted avg       0.97      0.98      0.98      6463
#
# Category feature : Refugees
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98      6237
#          1.0       0.09      0.01      0.02       226
#
#    micro avg       0.96      0.96      0.96      6463
#    macro avg       0.53      0.50      0.50      6463
# weighted avg       0.93      0.96      0.95      6463
#
# Category feature : Death
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      6155
#          1.0       0.07      0.01      0.01       308
#
#    micro avg       0.95      0.95      0.95      6463
#    macro avg       0.51      0.50      0.49      6463
# weighted avg       0.91      0.95      0.93      6463
#
# Category feature : Other_aid
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.99      0.93      5620
#          1.0       0.13      0.01      0.01       843
#
#    micro avg       0.87      0.87      0.87      6463
#    macro avg       0.50      0.50      0.47      6463
# weighted avg       0.77      0.87      0.81      6463
#
# Category feature : Infrastructure_related
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96      6033
#          1.0       0.03      0.00      0.00       430
#
#    micro avg       0.93      0.93      0.93      6463
#    macro avg       0.48      0.50      0.48      6463
# weighted avg       0.87      0.93      0.90      6463
#
# Category feature : Transport
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      6138
#          1.0       0.00      0.00      0.00       325
#
#    micro avg       0.95      0.95      0.95      6463
#    macro avg       0.47      0.50      0.49      6463
# weighted avg       0.90      0.95      0.92      6463
#
# Category feature : Buildings
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97      6151
#          1.0       0.00      0.00      0.00       312
#
#    micro avg       0.95      0.95      0.95      6463
#    macro avg       0.48      0.50      0.49      6463
# weighted avg       0.91      0.95      0.93      6463
#
# Category feature : Electricity
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6334
#          1.0       0.05      0.01      0.01       129
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.52      0.50      0.50      6463
# weighted avg       0.96      0.98      0.97      6463
# Category feature : Tools
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      6423
#          1.0       0.00      0.00      0.00        40
#
#    micro avg       0.99      0.99      0.99      6463
#    macro avg       0.50      0.50      0.50      6463
# weighted avg       0.99      0.99      0.99      6463
#
# Category feature : Hospitals
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6388
#          1.0       0.08      0.01      0.02        75
#
#    micro avg       0.99      0.99      0.99      6463
#    macro avg       0.53      0.51      0.51      6463
# weighted avg       0.98      0.99      0.98      6463
#
# Category feature : Shops
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      6430
#          1.0       0.00      0.00      0.00        33
#
#    micro avg       0.99      0.99      0.99      6463
#    macro avg       0.50      0.50      0.50      6463
# weighted avg       0.99      0.99      0.99      6463
#
# Category feature : Aid_centers
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6371
#          1.0       0.04      0.01      0.02        92
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.51      0.50      0.50      6463
# weighted avg       0.97      0.98      0.98      6463
#
# Category feature : Other_infrastructure
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98      6193
#          1.0       0.06      0.00      0.01       270
#
#    micro avg       0.96      0.96      0.96      6463
#    macro avg       0.51      0.50      0.49      6463
# weighted avg       0.92      0.96      0.94      6463
#
# Category feature : Weather_related
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.94      0.84      4654
#          1.0       0.57      0.19      0.28      1809
#
#    micro avg       0.73      0.73      0.73      6463
#    macro avg       0.66      0.57      0.56      6463
# weighted avg       0.70      0.73      0.68      6463
#
# Category feature : Floods
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96      5934
#          1.0       0.16      0.01      0.02       529
#
#    micro avg       0.91      0.91      0.91      6463
#    macro avg       0.54      0.50      0.49      6463
# weighted avg       0.86      0.91      0.88      6463
#
# Category feature : Storm
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.99      0.95      5859
#          1.0       0.45      0.12      0.18       604
#
#    micro avg       0.90      0.90      0.90      6463
#    macro avg       0.68      0.55      0.57      6463
# weighted avg       0.87      0.90      0.88      6463
#
# Category feature : Fire
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6380
#          1.0       0.00      0.00      0.00        83
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.49      0.50      0.50      6463
# weighted avg       0.97      0.98      0.98      6463
#
# Category feature : Earthquake
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.99      0.95      5866
#          1.0       0.60      0.14      0.23       597
#
#    micro avg       0.91      0.91      0.91      6463
#    macro avg       0.76      0.57      0.59      6463
# weighted avg       0.89      0.91      0.89      6463
#
# Category feature : Cold
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      6331
#          1.0       0.00      0.00      0.00       132
#
#    micro avg       0.98      0.98      0.98      6463
#    macro avg       0.49      0.50      0.49      6463
# weighted avg       0.96      0.98      0.97      6463
#
# Category feature : Other_weather
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97      6098
#          1.0       0.11      0.01      0.01       365
#
#    micro avg       0.94      0.94      0.94      6463
#    macro avg       0.52      0.50      0.49      6463
# weighted avg       0.90      0.94      0.92      6463
#
# Category feature : Direct_report
# .................................................................
#
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.95      0.88      5196
#          1.0       0.38      0.11      0.18      1267
#
#    micro avg       0.79      0.79      0.79      6463
#    macro avg       0.60      0.53      0.53      6463
# weighted avg       0.73      0.79      0.74      6463

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# From the above cells, we can see that while using an AdaBoost algorithm did not increase overrall accuracy, it increased overall f1 score by 1.2 percentage points. Training of the algorithm using GridSearch took over 3 hours. We could try other techniques such as using custom estimators.

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
# Save the model to a pickle file
filename = projects_dir + 'Classifier.model'
pickle.dump(cv, open(filename, 'wb'))

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
